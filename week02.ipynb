# %% [markdown]
# <a href="https://colab.research.google.com/github/RaymondMukasa256/isys5002-python-outlines/blob/main/week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Personalised input & special references
# ##1. Collect User input

# %%
#collect basic user inputs
userName = input("what's your name ?")
favColor = input("What's your favourite color ?")
favFood = input("What's your favourite food?")
userAge = input("What's your age?")

#display output of captured inputs
print("Name:",userName)
print("Favourite color:", favColor)
print("Favourite Food:", favFood)
print("Age:", userAge)
# Out:
# what's your name ?Raymond Bryan Mukasa
# What's your favourite color ?Green
# What's your favourite food?Pizza
# What's your age?28
# Name: Raymond Bryan Mukasa
# Favourite color: Green
# Favourite Food: Pizza
# Age: 28

# %% [markdown]
# ##Output personalized information

# %%
print("Greetings," + userName + "! Your favourite color is" + favColor + "and you love eating" + favFood + "." )
# Out:
# Greetings,Raymond Mukasa Bryan! Your favourite color isPinkand you love eatingMatooke.

# %% [markdown]
# ##Extended output personalized information

# %%
userTask = input("your favorite task at work?")
userFriend = input("your best friend is?")

print ("Good evening," + userName + ", how is " + userFriend + ", your best friend doing ? This year marks your " + userDay + " th birthday. Apart from writing reports, you like" + userTask + "every morning at work.")
# Out:
# your favorite task at work?Making jokes
# your best friend is?Bobwine
# Good evening,Raymond Mukasa Bryan, how is Bobwine, your best friend doing ? This year marks your 28 th birthday. Apart from writing reports, you likeMaking jokesevery morning at work.

# %% [markdown]
# ##Experiment with input()

# %%
userFaith = input("what's your religion ?")
print ("People who are", userFaith , "have good morals.")
# Out:
# what's your religion ?Christain
# People who are Christain have good morals.

# %% [markdown]
# ##String manipulation

# %%
print ( "Your name on official document appears as ", userName.upper() + "!", '\n' ,"your age appears as", userAge, ".")
# Out:
# Your name on official document appears as  RAYMOND BRYAN MUKASA!
#  your age appears as 28 .

# %%
userBirth = input("What's your birth year ?")
# Out:
# What's your birth year ?2000

# %%
import datetime

current_year = datetime.datetime.now().year
birth_year = int(userBirth)

userAge = current_year - birth_year

print("Your age is", userAge)
# Out:
# Your age is 26

# %% [markdown]
# #User Preference Survey

# %%
# survey programme

# Ask the user for their preferences
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")
favourite_food = input("What's your favourite food? ")
favourite_movie = input("What's your favourite movie? ")
fatherName = input("What's your father's name? ")
motherName = input("What's your mother's name? ")
gender = input("What's your gender? ")
userFaith = input("What's your religion? ")



# Construct and display a summary message
print("\nHello, " + name + "!")
print("Your favourite colour is " + favourite_colour + ", you love " + favourite_food +
      ", and your favourite movie is " + favourite_movie + ".")
print("\nYour father's name is " + fatherName + ", and your mother's name is " + motherName + ".")
print("\nYour gender is " + gender + ", and your religion is " + userFaith + ".")

# %% [markdown]
# #Crafting Weather Menu

# %%
# Displaying the weather menu options with improved primitive UI
print("************ Weather Menu ************")
print("* 1. Check Temperature               *")
print("* 2. Check Humidity                  *")
print("* 3. Check Wind Speed                *")
print("* 4. Exit                            *")
print("**************************************")

# Prompting the user to enter their choice
choice = input("Enter your choice (1-4): ")
print("You selected option:", choice)

# Example of a simple decision structure based on the user's choice
if choice == "1":
    print("You chose to check the temperature.")
elif choice == "2":
    print("You chose to check the humidity.")
elif choice == "3":
    print("You chose to check the wind speed.")
elif choice == "4":
    print("Exiting the program.")
else:
    print("Invalid choice. Please select a valid option.")
