# %% [markdown]
# <a href="https://colab.research.google.com/github/RaymondMukasa256/isys5002-python-outlines/blob/main/week04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basic Calculator program

# %%
# Define the calculator functions
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b

# Display the menu
print("Simple Calculator Menu")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

# Get the user's choice
choice = input("Enter your choice (1-4): ")

# Get the two numbers from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Perform the chosen operation
if choice == "1":
    result = add(num1, num2)
elif choice == "2":
    result = subtract(num1, num2)
elif choice == "3":
    result = multiply(num1, num2)
elif choice == "4":
    result = divide(num1, num2)
else:
    result = "Invalid choice."

# Display the result
print("Result:", result)
# Out:
# Simple Calculator Menu
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Enter your choice (1-4): 1
# Enter the first number: 5
# Enter the second number: 9
# Result: 14.0

# %% [markdown]
# ##Display menu

# %%
#function to display menu
import pyinputplus as pyip
def get_operation():
    print("Simple Calculator Menu")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Modulus")
    choice = pyip.inputChoice(['1', '2', '3', '4', '5'], prompt="Enter your choice (1-5): ")
    return choice

# %%
#function to get number
def get_number(prompt):
    return float(input(prompt))

# %%
#function to perform calculation
def perform_calculation(operation, num1, num2):
    if operation == "1":
        return add(num1, num2)
    elif operation == "2":
        return subtract(num1, num2)
    elif operation == "3":
        return multiply(num1, num2)
    elif operation == "4":
        return divide(num1, num2)
    elif operation == "5":
        return modulus(num1, num2)
    else:
        return "Invalid choice."

# %%
#add the fuctions for operations
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
  if b == 0:
    return "Error: cannot divide by zero"
  else:
    return a / b

def modulus(a, b):
  if b == 0:
    return "Error: cannot perform modulus with zero divisor"
  else:
    return a % b

# %%
perform_calculation("3", 8, 4)
# Out:
# 32

# %%
# !pip install pyinputplus
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyinputplus: filename=pyinputplus-0.2.12-py3-none-any.whl size=11349 sha256=794a4642fc1b6b7ddcac6a77d7efc53c974795eed4a11b36c4daa3205c749c49
#   Stored in directory: /root/.cache/pip/wheels/f7/b4/80/8bb0c986a6bff982c948af5e937c4b6a2b65ad4ef16c5cd671
# ...
#   Created wheel for pysimplevalidate: filename=pysimplevalidate-0.2.12-py3-none-any.whl size=16224 sha256=a8f3fee73b11fcd5abb8207c53a9b2338812c7cd534bcb3fc84575da4532b603
#   Stored in directory: /root/.cache/pip/wheels/af/60/74/a8483e5a1f06657d316ef4004723dfb6e1fda2e716973a9111
# ...

# %%
import pyinputplus as pyip

# Ensures the user enters a float
number = pyip.inputFloat("Enter a number: ")

# Ensures the user enters one of the provided choices
choice = pyip.inputChoice(['1', '2', '3', '4'], prompt="Enter your choice (1-4): ")
# Out:
# Enter a number: 4
# Enter your choice (1-4): 1

# %%
operation = get_operation()
num1 = pyip.inputFloat("Enter the first number: ")
num2 = pyip.inputFloat("Enter the second number: ")
result = perform_calculation(operation, num1, num2)
print("Result:", result)
# Out:
# Simple Calculator Menu
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Modulus
# Enter your choice (1-5): 2
# Enter the first number: 5
# Enter the second number: 7
# Result: -2.0
